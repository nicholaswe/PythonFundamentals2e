# %% [markdown]
# # 3.8 `for` Statement

# %% [markdown]
# In python, a string is a sequence of characters.
# The argument "end" applies whatever you want after each value in the looping

# %%
for character in 'Programming':
    print(character, end='|')
# Out:
# P|r|o|g|r|a|m|m|i|n|g|

# %% [markdown]
# ### Function `print`’s `sep` Keyword Argument

# %%
print(10, 20, 30, sep=', ')
# Out:
# 10, 20, 30

# %% [markdown]
# ## 3.8.1 Iterables, Lists and Iterators

# %%
total = 0

# %% [markdown]
# Below we are iterating a list "[, ..., ]":

# %%
for number in [2, -3, 0, 17, 9]:
    total = total + number
    print("we are in the number ", number, " and the partial total is", total)
# Out:
# we are in the number  2  and the partial total is 2
# we are in the number  -3  and the partial total is -1
# we are in the number  0  and the partial total is -1
# we are in the number  17  and the partial total is 16
# we are in the number  9  and the partial total is 25

# %%
total
# Out:
# 25

# %% [markdown]
# ## 3.8.2 Built-In `range` Function and Generators

# %%
for counter in range(10):
    print("We are in counter", counter, end='\n')
# Out:
# We are in counter 0
# We are in counter 1
# We are in counter 2
# We are in counter 3
# We are in counter 4
# We are in counter 5
# We are in counter 6
# We are in counter 7
# We are in counter 8
# We are in counter 9

# %%
##########################################################################
# (C) Copyright 2019 by Deitel & Associates, Inc. and                    #
# Pearson Education, Inc. All Rights Reserved.                           #
#                                                                        #
# DISCLAIMER: The authors and publisher of this book have used their     #
# best efforts in preparing the book. These efforts include the          #
# development, research, and testing of the theories and programs        #
# to determine their effectiveness. The authors and publisher make       #
# no warranty of any kind, expressed or implied, with regard to these    #
# programs or to the documentation contained in these books. The authors #
# and publisher shall not be liable in any event for incidental or       #
# consequential damages in connection with, or arising out of, the       #
# furnishing, performance, or use of these programs.                     #
##########################################################################
